# %%
# Transcribing_DNA_into_RNA
DNA = '...'
RNA = ''

translate = {
    "A":"A",
    "T":"U",
    "G":"G",
    "C":"C"
}

for nu in DNA:
    if nu in translate:
        RNA += (translate[nu])
print(RNA)
# Out:
# ...
