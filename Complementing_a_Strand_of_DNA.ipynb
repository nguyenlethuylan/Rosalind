# %%
# Complementing a Strand of DNA
string = '...'
complement = ''
translate = {
    "A": "T",
    "T": "A",
    "G": "C",
    "C": "G"
}

# Generating the reverse complement
for nu in string:
    if nu in translate:
        complement = translate[nu] + complement

print(f'The reverse complement is: {complement}')
# Out:
# The reverse complement is: ...
